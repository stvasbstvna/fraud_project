# %% [markdown]
# # 05 - Mitigation testing
#
# Evaluate augmentation, intent/action features, calibration, and the small hybrid condition.
#
# This notebook is a workflow placeholder. It must not be presented as completed analysis until data provenance, licensing, and the frozen split are documented.
